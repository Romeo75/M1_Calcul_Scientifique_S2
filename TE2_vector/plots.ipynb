# %% [markdown]
# # Graphiques python pour l'EDO Scalaire du premier ordre
# ## Comparaison des solutions numériques avec la théorie
# ### Integration par la méthode d'euler
# * Pour un pas de 0.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label="fonction Num" )
fig1.plot( x2,y2, label="fonction Th" )
fig1.legend()
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.1.txt : 3 lignes d'entete
#  < Le graphique data/euler_0.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.1.pdf

# %% [markdown]
# * Pour un pas de 0.2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label="fonction Num" )
fig1.plot( x2,y2, label="fonction Th" )
fig1.legend()
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
euler_2 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.2.txt : 3 lignes d'entete
#  < Le graphique data/euler_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.2.pdf

# %%
from IPython.display import Markdown as md

rap= euler_2/euler_1

md(" On observe un rapport de $$ \\frac{ERROR_{0.2}}{ERROR_{0.1}} = "+"%f $$ "%(rap))
# Out:
#  On observe un rapport de $$ \frac{ERROR_{0.2}}{ERROR_{0.1}} = 1.728149 $$

# %% [markdown]
# Ce qui nous permet de deduire que la diminution du pas par un facteur 2 permet de diminuer l'arreur d'un facteur 2 environ.
# Ce qu'est en accord avec le cours car l'erreur globale de cette methode a un comportement de la forme: $$ \propto h $$, où h est le pas considéré.

# %% [markdown]
# ### Integration par la méthode des points milieux
#
# * Pour un pas de 0.1:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label="fonction Num" )
fig1.plot( x2,y2, label="fonction Th" )
fig1.legend()
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
pm_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.1.txt : 3 lignes d'entete
#  < Le graphique data/pm_0.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.1.pdf

# %% [markdown]
# * Pour un pas de 0.2:

# %%
### import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label=fonction_tab )
fig1.plot( x2,y2, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
pm_2 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.2.txt : 3 lignes d'entete
#  < Le graphique data/pm_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.2.pdf

# %%
from IPython.display import Markdown as md

rap2= pm_2/pm_1

md(" On observe un rapport de $$ \\frac{ERROR_{0.2}}{ERROR_{0.1}} = "+"%f $$ "%(rap2))
# Out:
#  On observe un rapport de $$ \frac{ERROR_{0.2}}{ERROR_{0.1}} = 3.549541 $$

# %% [markdown]
# Ce qui nous permet de deduire que la diminution du pas par un facteur 2 permet de diminuer l'arreur d'un facteur 4 environ.
# Ce qu'est en accord avec le cours car l'erreur globale de cette methode a un comportement de la forme: $$ \propto h^2 $$, où h est le pas considéré.

# %% [markdown]
# ### Integration par la methode RK4
# * Pour un pas de 0.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk_0.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label="fonction Num" )
fig1.plot( x2,y2, label="fonction Th" )
fig1.legend()
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
rk_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk_0.1.txt : 3 lignes d'entete
#  < Le graphique data/rk_0.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk_0.1.pdf

# %% [markdown]
# * Pour un pas de 0.2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")



# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label="fonction Num" )
fig1.plot( x2,y2, label="fonction Th" )
fig1.legend()
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
rk_2 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk_0.2.txt : 3 lignes d'entete
#  < Le graphique data/rk_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk_0.2.pdf

# %%
from IPython.display import Markdown as md

rap3= rk_2/rk_1

md(" On observe un rapport de $$ \\frac{ERROR_{0.2}}{ERROR_{0.1}} = "+"%f $$ "%(rap3))
# Out:
#  On observe un rapport de $$ \frac{ERROR_{0.2}}{ERROR_{0.1}} = 14.086345 $$

# %% [markdown]
# Ce qui nous permet de deduire que la diminution du pas par un facteur 2 permet de diminuer l'arreur d'un facteur $14 (\approx 16 \pm 2)$ environ.
# Ce qui commence à s'éloigner un peu de la théorie vue en cours car l'erreur globale de cette methode a un comportement de la forme: $$ \propto h^4 $$, où h est le pas considéré.

# %% [markdown]
# ## Observations Generales
#
# * On observe que lorsqu'on diminue le pas d'integration on diminue l'erreur maximale absolue entre la solution numérique et la solution analytique.
#
# * On voit que l'integrtion à partir de methodes d'integration d'ordre superieur permet de diminuer l'erreur maximale considérablement. Par exemple la methode d'Euler a une erreur qui semble linéaire avce le pas. Alors que la methode des points milieux nous permet d'avoir une erreur qui varie comme le carré du pas et avec celle de RK4 on a une erreur en puissance 4 du pas.
#
# * Une étude plus détaillé des erreurs en fonction des pas d'integration nous permettrait d'optimiser cette grandeur dans l'objectif de minimiser l'erreur globale.

# %% [markdown]
# ## Optimisation du pas d'integration

# %% [markdown]
# ### Pour un pas de 0.01
#
# * Par la méthode d'Euler

# %%
### import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.01.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label="fonction Num" )
fig1.plot( x2,y2, label="fonction Th" )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.legend()
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
euler_01 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.01.txt : 3 lignes d'entete
#  < Le graphique data/euler_0.01.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.01.pdf

# %%
from IPython.display import Markdown as md

rap4= euler_1/euler_01

md(" On observe un rapport de $$ \\frac{ERROR_{0.1}}{ERROR_{0.01}} = "+"%f $$ "%(rap4))
# Out:
#  On observe un rapport de $$ \frac{ERROR_{0.1}}{ERROR_{0.01}} = 8.602415 $$

# %% [markdown]
# * Par la méthode des points milieux

# %%
### import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.01.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label=fonction_tab )
fig1.plot( x2,y2, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
pm_01 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.01.txt : 3 lignes d'entete
#  < Le graphique data/pm_0.01.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.01.pdf

# %%
from IPython.display import Markdown as md

rap5= pm_1/pm_01

md(" On observe un rapport de $$ \\frac{ERROR_{0.1}}{ERROR_{0.01}} = "+"%f $$ "%(rap5))
# Out:
#  On observe un rapport de $$ \frac{ERROR_{0.1}}{ERROR_{0.01}} = 90.062070 $$

# %% [markdown]
# * Par la méthode de RK4

# %%
### import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk_0.01.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label=fonction_tab )
fig1.plot( x2,y2, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
rk_01 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk_0.01.txt : 3 lignes d'entete
#  < Le graphique data/rk_0.01.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk_0.01.pdf

# %%
from IPython.display import Markdown as md

rap6= rk_1/rk_01

md(" On observe un rapport de $$ \\frac{ERROR_{0.1}}{ERROR_{0.01}} = "+"%f $$ "%(rap6))
# Out:
#  On observe un rapport de $$ \frac{ERROR_{0.1}}{ERROR_{0.01}} = 27.500000 $$

# %% [markdown]
# ### Pour un pas de 0.001
#
# * Par la méthode d'Euler

# %%
### import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.001.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label=fonction_tab )
fig1.plot( x2,y2, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
euler_001 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.001.txt : 3 lignes d'entete
#  < Le graphique data/euler_0.001.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.001.pdf

# %%
from IPython.display import Markdown as md

rap7= euler_01/euler_001

md(" On observe un rapport de $$ \\frac{ERROR_{0.01}}{ERROR_{0.001}} = "+"%f $$ "%(rap7))
# Out:
#  On observe un rapport de $$ \frac{ERROR_{0.01}}{ERROR_{0.001}} = 9.831335 $$

# %% [markdown]
# * Par la méthode des points milieux

# %%
### import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.001.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
figure, (fig1, fig2) = plt.subplots(2)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=8)
fig1.plot( x,y, label=fonction_tab )
fig1.plot( x2,y2, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
pm_001 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.001.txt : 3 lignes d'entete
#  < Le graphique data/pm_0.001.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.001.pdf

# %%
from IPython.display import Markdown as md

rap8= pm_01/pm_001

md(" On observe un rapport de $$ \\frac{ERROR_{0.01}}{ERROR_{0.001}} = "+"%f $$ "%(rap8))
# Out:
#  On observe un rapport de $$ \frac{ERROR_{0.01}}{ERROR_{0.001}} = 22.692300 $$

# %% [markdown]
# * Par la méthode de RK4

# %%
### import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk_0.001.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]
y  = tab[:,1]

x2 = tab[:,0]
y2 = tab[:,2]

x3 = tab[:,0]
y3 = tab[:,3]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Solutions Analytique et numérique \n" + titre, fontsize=10)
fig1.plot( x,y, label=fonction_tab )
fig1.plot( x2,y2, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=10)
fig2.plot( x3,y3, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig2.grid()



#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)



plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
rk_001 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk_0.001.txt : 3 lignes d'entete
#  < Le graphique data/rk_0.001.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk_0.001.pdf

# %%
from IPython.display import Markdown as md

rap9 = rk_01/rk_001

md(" On observe un rapport de $$ \\frac{ERROR_{0.01}}{ERROR_{0.001}} = "+"%f $$ "%(rap9))
# Out:
#  On observe un rapport de $$ \frac{ERROR_{0.01}}{ERROR_{0.001}} = 0.296297 $$

# %% [markdown]
# ## Conclusions generales sur l'optimisation du pas
#
# On observe que:
# * BlaBlaBla
#
# * rk4 minimise l'erreur pour un pas de l'ordre de 0.01

# %% [markdown]
# # Graphiques python pour l'EDO Scalaire du second ordre

# %% [markdown]
# ## Solution analytique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "pendule.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure(2,figsize=(w, h), dpi=d)
plt.title(" Solution Analytique \n" + titre, fontsize=10)
plt.plot(x,y_calc, label="fonction Num")                # <== choix de la legende
plt.grid()
plt.xlabel("Temps (en SI)")                                # <== variable d'abscisse
plt.ylabel("Angle (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
# Out:
#  > fichier pendule.txt : 4 lignes d'entete
#  < Le graphique pendule.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular pendule.pdf

# %% [markdown]
# ## Comparaison de la solution numerique non linéaire avec la solution analytique linéaire

# %% [markdown]
# * Pour un pas de 0.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "rk4_0.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

DeltaY = y_calc - y_th
DeltaVy = Vy_calc - Vy_th

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Ecart en position de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig1.plot( x,DeltaY, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en vitesse de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig2.plot( x,DeltaVy, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier rk4_0.1.txt : 4 lignes d'entete
#  < Le graphique rk4_0.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular rk4_0.1.pdf

# %% [markdown]
# ### Diagrammes de phase

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "rk4_0.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure(2,figsize=(w, h), dpi=d)
plt.title(" Diagrammes de phases Analytiques et numériques\n" + titre, fontsize=10)
plt.plot(y_calc, Vy_calc, label="fonction Num")                # <== choix de la legende
plt.plot(y_th, Vy_th, label="fonction Calc")
plt.xlabel("Angle (en SI)")                                # <== variable d'abscisse
plt.ylabel("Impulsion (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
plt.grid()
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier rk4_0.1.txt : 4 lignes d'entete
#  < Le graphique rk4_0.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular rk4_0.1.pdf

# %% [markdown]
# * Pour un pas de 0.01

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "rk4_0.01.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

DeltaY = y_calc - y_th
DeltaVy = Vy_calc - Vy_th

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Ecart en position de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig1.plot( x,DeltaY, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en vitesse de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig2.plot( x,DeltaVy, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier rk4_0.01.txt : 4 lignes d'entete
#  < Le graphique rk4_0.01.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular rk4_0.01.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "rk4_0.01.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure( figsize=(w, h), dpi=d )
plt.title(" Diagrammes de phases Analytiques et numériques\n" + titre, fontsize=10)
plt.plot(y_calc, Vy_calc, label="fonction Num")                # <== choix de la legende
plt.plot(y_th, Vy_th, label="fonction Calc")
plt.xlabel("Angle (en SI)")                                # <== variable d'abscisse
plt.ylabel("Impulsion (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
plt.grid()
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier rk4_0.01.txt : 4 lignes d'entete
#  < Le graphique rk4_0.01.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular rk4_0.01.pdf

# %% [markdown]
# ## Evolution de la solution numérique avec l'augmentation de la vitesse

# %% [markdown]
# ### Régime Apériodique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "rk4_0.01_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier rk4_0.01_2.1.txt : 4 lignes d'entete
#  < Le graphique rk4_0.01_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular rk4_0.01_2.1.pdf

# %% [markdown]
# ### Régime périodique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "rk4_0.01.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier rk4_0.01.txt : 4 lignes d'entete
#  < Le graphique rk4_0.01.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular rk4_0.01.pdf
