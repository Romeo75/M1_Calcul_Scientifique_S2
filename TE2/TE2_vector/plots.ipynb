# %% [markdown]
# # Graphiques python pour l'EDO Scalaire du second ordre

# %% [markdown]
# ## Solution analytique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pendule.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure(2,figsize=(w, h), dpi=d)
plt.title(" Solution Analytique \n" + titre, fontsize=10)
plt.plot(x,y_calc, label="fonction Num")                # <== choix de la legende
plt.grid()
plt.xlabel("Temps (en SI)")                                # <== variable d'abscisse
plt.ylabel("Angle (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
# Out:
#  > fichier data/pendule.txt : 4 lignes d'entete
#  < Le graphique data/pendule.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pendule.pdf

# %% [markdown]
# ## Comparaison de la solution numerique non linéaire avec la solution analytique linéaire

# %% [markdown]
# * Pour un pas de 0.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

DeltaY = y_calc - y_th
DeltaVy = Vy_calc - Vy_th

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Ecart en position de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig1.plot( x,DeltaY, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en vitesse de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig2.plot( x,DeltaVy, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.1.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.1.pdf

# %% [markdown]
# ### Diagrammes de phase

# %% [markdown]
# * Pour un pas de 0.1:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure(2,figsize=(w, h), dpi=d)
plt.title(" Diagrammes de phases Analytiques et numériques\n" + titre, fontsize=10)
plt.plot(y_calc, Vy_calc, label="fonction Num")                # <== choix de la legende
plt.plot(y_th, Vy_th, label="fonction Calc")
plt.xlabel("Angle (en SI)")                                # <== variable d'abscisse
plt.ylabel("Impulsion (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
plt.grid()
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.1.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.1.pdf

# %% [markdown]
# * Pour un pas de 0.01

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.01.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

DeltaY = y_calc - y_th
DeltaVy = Vy_calc - Vy_th

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Ecart en position de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig1.plot( x,DeltaY, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en vitesse de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig2.plot( x,DeltaVy, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.01.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.01.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.01.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.01.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure( figsize=(w, h), dpi=d )
plt.title(" Diagrammes de phases Analytiques et numériques\n" + titre, fontsize=10)
plt.plot(y_calc, Vy_calc, label="fonction Num")                # <== choix de la legende
plt.plot(y_th, Vy_th, label="fonction Calc")
plt.xlabel("Angle (en SI)")                                # <== variable d'abscisse
plt.ylabel("Impulsion (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
plt.grid()
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.01.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.01.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.01.pdf

# %% [markdown]
# ## Etude de l'influence du pas d'intégration sur la solution numérique en régime périodique et apériodique

# %% [markdown]
# Dans cette partie on souhaite analyser les differentes méthodes en vérifiant la conservation de l'énergie mécanique.

# %% [markdown]
# * ## Pour un pas de 0.1:

# %% [markdown]
# ### Régime périodique:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.1_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.1_0.2.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.1_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.1_0.2.pdf

# %% [markdown]
# ### Régime apériodique:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.1.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.1.pdf

# %% [markdown]
# * ## Pour un pas de 0.01:

# %% [markdown]
# ### Régime Apériodique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.01_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.01_2.1.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.01_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.01_2.1.pdf

# %% [markdown]
# ### Régime périodique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.01.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.01.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.01.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.01.pdf

# %% [markdown]
# ## Remarques et commentaires pour la methode rk4
#
# * On observe que rk4 obtien des résultats consistants avec la diminution du pas.
# * Pour le régime périodique on observe une erreur maximale d'environ 0.34%.
# * On peut conclure que cette méthode nous permet d'obtenir des résultats cohérents et invariants dans la cas du régime périodique avec un pas de l'ordre de 0.1.
#
# * On observe que dans le cas apériodique la méthode donne des résultats incoherents pour les deux valeurs du pas car on observe que l'énergie mécanique en fonction du temps.

# %% [markdown]
# ## Pour euler

# %% [markdown]
# ## Solution analytique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.1_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure(2,figsize=(w, h), dpi=d)
plt.title(" Solution Analytique \n" + titre, fontsize=10)
plt.plot(x,y_calc, label="fonction Num")                # <== choix de la legende
plt.grid()
plt.xlabel("Temps (en SI)")                                # <== variable d'abscisse
plt.ylabel("Angle (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
# Out:
#  > fichier data/euler_0.1_0.2.txt : 4 lignes d'entete
#  < Le graphique data/euler_0.1_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.1_0.2.pdf

# %% [markdown]
# ## Comparaison de la solution numerique non linéaire avec la solution analytique linéaire

# %% [markdown]
# * Pour un pas de 0.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.1_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

DeltaY = y_calc - y_th
DeltaVy = Vy_calc - Vy_th

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Ecart en position de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig1.plot( x,DeltaY, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en vitesse de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig2.plot( x,DeltaVy, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.1_0.2.txt : 4 lignes d'entete
#  < Le graphique data/euler_0.1_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.1_0.2.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.1_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

DeltaY = y_calc - y_th
DeltaVy = Vy_calc - Vy_th

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Ecart en position de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig1.plot( x,DeltaY, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en vitesse de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig2.plot( x,DeltaVy, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.1_2.1.txt : 4 lignes d'entete
#  < Le graphique data/euler_0.1_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.1_2.1.pdf

# %% [markdown]
# ### Diagrammes de phase

# %% [markdown]
# * Pour un pas de 0.1:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.1_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure(2,figsize=(w, h), dpi=d)
plt.title(" Diagrammes de phases Analytiques et numériques\n" + titre, fontsize=10)
plt.plot(y_calc, Vy_calc, label="fonction Num")                # <== choix de la legende
plt.plot(y_th, Vy_th, label="fonction Calc")
plt.xlabel("Angle (en SI)")                                # <== variable d'abscisse
plt.ylabel("Impulsion (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
plt.grid()
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.1_0.2.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.1_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.1_0.2.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.1_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure(2,figsize=(w, h), dpi=d)
plt.title(" Diagrammes de phases Analytiques et numériques\n" + titre, fontsize=10)
plt.plot(y_calc, Vy_calc, label="fonction Num")                # <== choix de la legende
plt.plot(y_th, Vy_th, label="fonction Calc")
plt.xlabel("Angle (en SI)")                                # <== variable d'abscisse
plt.ylabel("Impulsion (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
plt.grid()
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.1_2.1.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.1_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.1_2.1.pdf

# %% [markdown]
# * Pour un pas de 0.01

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.01_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

DeltaY = y_calc - y_th
DeltaVy = Vy_calc - Vy_th

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Ecart en position de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig1.plot( x,DeltaY, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en vitesse de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig2.plot( x,DeltaVy, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.01_0.2.txt : 4 lignes d'entete
#  < Le graphique data/euler_0.01_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.01_0.2.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/rk4_0.01.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure( figsize=(w, h), dpi=d )
plt.title(" Diagrammes de phases Analytiques et numériques\n" + titre, fontsize=10)
plt.plot(y_calc, Vy_calc, label="fonction Num")                # <== choix de la legende
plt.plot(y_th, Vy_th, label="fonction Calc")
plt.xlabel("Angle (en SI)")                                # <== variable d'abscisse
plt.ylabel("Impulsion (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
plt.grid()
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/rk4_0.01.txt : 4 lignes d'entete
#  < Le graphique data/rk4_0.01.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/rk4_0.01.pdf

# %% [markdown]
# ## Etude de l'influence du pas d'intégration sur la solution numérique en régime périodique et apériodique

# %% [markdown]
# Dans cette partie on souhaite analyser les differentes méthodes en vérifiant la conservation de l'énergie mécanique.

# %% [markdown]
# * ## Pour un pas de 0.1:

# %% [markdown]
# ### Régime périodique:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.1_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.1_0.2.txt : 4 lignes d'entete
#  < Le graphique data/euler_0.1_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.1_0.2.pdf

# %% [markdown]
# ### Régime apériodique:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.1_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.1_2.1.txt : 4 lignes d'entete
#  < Le graphique data/euler_0.1_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.1_2.1.pdf

# %% [markdown]
# * ## Pour un pas de 0.01:

# %% [markdown]
# ### Régime Apériodique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.01_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.01_2.1.txt : 4 lignes d'entete
#  < Le graphique data/euler_0.01_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.01_2.1.pdf

# %% [markdown]
# ### Régime périodique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/euler_0.01_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/euler_0.01_0.2.txt : 4 lignes d'entete
#  < Le graphique data/euler_0.01_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/euler_0.01_0.2.pdf

# %% [markdown]
# ## Pour pm

# %% [markdown]
# ## Solution analytique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.1_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure(2,figsize=(w, h), dpi=d)
plt.title(" Solution Analytique \n" + titre, fontsize=10)
plt.plot(x,y_calc, label="fonction Num")                # <== choix de la legende
plt.grid()
plt.xlabel("Temps (en SI)")                                # <== variable d'abscisse
plt.ylabel("Angle (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
# Out:
#  > fichier data/pm_0.1_0.2.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.1_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.1_0.2.pdf

# %% [markdown]
# ## Comparaison de la solution numerique non linéaire avec la solution analytique linéaire

# %% [markdown]
# * Pour un pas de 0.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.1_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

DeltaY = y_calc - y_th
DeltaVy = Vy_calc - Vy_th

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Ecart en position de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig1.plot( x,DeltaY, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en vitesse de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig2.plot( x,DeltaVy, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.1_0.2.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.1_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.1_0.2.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.1_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

DeltaY = y_calc - y_th
DeltaVy = Vy_calc - Vy_th

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Ecart en position de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig1.plot( x,DeltaY, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en vitesse de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig2.plot( x,DeltaVy, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.1_2.1.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.1_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.1_2.1.pdf

# %% [markdown]
# ### Diagrammes de phase

# %% [markdown]
# * Pour un pas de 0.1:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.1_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure(2,figsize=(w, h), dpi=d)
plt.title(" Diagrammes de phases Analytiques et numériques\n" + titre, fontsize=10)
plt.plot(y_calc, Vy_calc, label="fonction Num")                # <== choix de la legende
plt.plot(y_th, Vy_th, label="fonction Calc")
plt.xlabel("Angle (en SI)")                                # <== variable d'abscisse
plt.ylabel("Impulsion (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
plt.grid()
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.1_0.2.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.1_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.1_0.2.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.1_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure(2,figsize=(w, h), dpi=d)
plt.title(" Diagrammes de phases Analytiques et numériques\n" + titre, fontsize=10)
plt.plot(y_calc, Vy_calc, label="fonction Num")                # <== choix de la legende
plt.plot(y_th, Vy_th, label="fonction Calc")
plt.xlabel("Angle (en SI)")                                # <== variable d'abscisse
plt.ylabel("Impulsion (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
plt.grid()
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.1_2.1.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.1_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.1_2.1.pdf

# %% [markdown]
# * Pour un pas de 0.01

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.01_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

DeltaY = y_calc - y_th
DeltaVy = Vy_calc - Vy_th

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Ecart en position de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig1.plot( x,DeltaY, label=fonction_tab )
fig1.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("y (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en vitesse de la solution Analytique et Numérique \n" + titre, fontsize=10)
fig2.plot( x,DeltaVy, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.01_0.2.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.01_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.01_0.2.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.01_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

y_th = tab[:,3]
Vy_th = tab[:,4]

Delta = y_calc - y_th

"""
# Creation du graphique
figure, plots = plt.subplots(2)
plots[0] = fig1
plots[1] = fig2
figure.tight_layout(pad=5.0)

fig1.set_title( " Phases Analytiques et numériques \n" + titre, fontsize=8)
fig1.plot( y_calc, Vy_calc, label="Num" )
fig1.legend()
fig1.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart entre les deux solutions \n" + titre, fontsize=8)
fig2.plot( y_th, Vy_th, label="Th" )
fig2.set_xlabel("Angle (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Impulsion (en SI)")                                   # <== variable d'ordonnee
fig2.grid()
"""
w = 10
h = 10
d = 70
plt.figure( figsize=(w, h), dpi=d )
plt.title(" Diagrammes de phases Analytiques et numériques\n" + titre, fontsize=10)
plt.plot(y_calc, Vy_calc, label="fonction Num")                # <== choix de la legende
plt.plot(y_th, Vy_th, label="fonction Calc")
plt.xlabel("Angle (en SI)")                                # <== variable d'abscisse
plt.ylabel("Impulsion (en SI)")                            # <== variable d'ordonnee
plt.legend(loc = 'upper right')
plt.grid()
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete)
euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.01_2.1.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.01_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.01_2.1.pdf

# %% [markdown]
# ## Etude de l'influence du pas d'intégration sur la solution numérique en régime périodique et apériodique

# %% [markdown]
# Dans cette partie on souhaite analyser les differentes méthodes en vérifiant la conservation de l'énergie mécanique.

# %% [markdown]
# * ## Pour un pas de 0.1:

# %% [markdown]
# ### Régime périodique:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.1_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.1_0.2.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.1_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.1_0.2.pdf

# %% [markdown]
# ### Régime apériodique:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.1_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.1_2.1.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.1_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.1_2.1.pdf

# %% [markdown]
# * ## Pour un pas de 0.01:

# %% [markdown]
# ### Régime Apériodique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.01_2.1.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.01_2.1.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.01_2.1.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.01_2.1.pdf

# %% [markdown]
# ### Régime périodique

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variable a modifier avant execution
nomfichier = "data/pm_0.01_0.2.txt" # <== fichier de donnees
#nomfichier2 = "data/euler_0.2.txt"
#nomfichier3 = "sin_centered.txt"
#nomfichier = "logistique.txt"                     # <== fichier de donnees

# Récupération du nom de la fonction tabulée
fonction_tab = nomfichier[ : nomfichier.rfind(".")]
#fonction_tab2 = nomfichier2[ : nomfichier2.rfind(".")]
#fonction_tab3 = nomfichier3[ : nomfichier3.rfind(".")]
nomgraph = fonction_tab+".pdf" #  idem fic. entree avec extension .pdf

try:      # ouverture du fichier de donnees
  fich = open(nomfichier, "r")
#  fich2 = open (nomfichier2, "r")
#  fich3 = open (nomfichier3, "r")
except:
  print(" ! Impossible d'ouvrir le fichier %s."%nomfichier )
  print(" ! Verifier le chemin.\n")
  exit()

# Lecture des lignes d'entete
ligne = fich.readline().replace("\n","") # sans caractere de fin de ligne
entete= [ ]
while( ligne[0] == "#" ):
   entete.append( ligne[1:] )
   ligne =  fich.readline().replace("\n","")
fich.close()
print( " > fichier %s : %d lignes d'entete"%( nomfichier, len(entete) ) )

# concatenation des entetes en une seule ligne de titre :
titre = " ".join(entete)

# Lecture des donnees du fichier :
tab = np.loadtxt( nomfichier, dtype="float")
#tab2 = np.loadtxt( nomfichier2, dtype="float")
#tab3 = np.loadtxt( nomfichier3, dtype="float")

# Creation des listes d'abscisses/ordonnees : 1ere et 2eme colonnes
x  = tab[:,0]

y_calc  = tab[:,1]
Vy_calc = tab[:,2]

Em = tab[:,5]

# Creation du graphique
w = 10
h = 10
d = 70
figure, (fig1, fig2) = plt.subplots(2,figsize=(w, h), dpi=d)
figure.tight_layout(pad=4.0)

fig1.set_title( " Diagrame de phase de la solution numérique \n" + titre, fontsize=10)
fig1.plot( y_calc,Vy_calc, label=fonction_tab )
fig1.set_xlabel("y (en SI)")                                   # <== variable d'abscisse
fig1.set_ylabel("Vy (en SI)")                                   # <== variable d'ordonnee
fig1.grid()

fig2.set_title( " Ecart en Energie de la solution Numérique et la valeur initiale \n" + titre, fontsize=10)
fig2.plot( x,Em, label=fonction_tab )
fig2.set_xlabel("temps (en SI)")                                   # <== variable d'abscisse
fig2.set_ylabel("Em (en SI)")                                   # <== variable d'ordonnee
fig2.grid()


#plt.plot(x, y, label=fonction_tab)                # <== choix de la legende
#plt.loglog(x,y, label=fonction_tab)
#plt.loglog(x2,y2, label=fonction_tab2)
#plt.loglog(x3,y3, label=fonction_tab3)


plt.autoscale(enable=True, axis='both', tight=None)

#plt.legend()
fig = plt.gcf()
fig.savefig(nomgraph) # sauvegarde du fichier au format PDF
print(" < Le graphique %s a ete cree."%(nomgraph) )
print("   \tVous pouvez le visualiser avec :  okular %s"%(nomgraph))

plt.show()
plt.clf() # nettoyage ('clear figure')

#print(entete[1])
#euler_1 = float(entete[1][ entete[1].rfind(":") + 1 :])
#print(max1)
# Out:
#  > fichier data/pm_0.01_0.2.txt : 4 lignes d'entete
#  < Le graphique data/pm_0.01_0.2.pdf a ete cree.
#    	Vous pouvez le visualiser avec :  okular data/pm_0.01_0.2.pdf
