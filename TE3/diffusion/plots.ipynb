# %% [markdown]
# # Diffusion

# %% [markdown]
# ## Méthode explicite
# ### Pour  $ \alpha = 0.1$ et $ N_t = 1000$

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-sin/explicite-0.10-1000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=1000
#  Le graphique 'data-sin/explicite-0.10-1000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# ## Pour $ \alpha = 0.1$ et $ N_t = 10000$

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-sin/explicite-0.10-10000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=10000
#  Le graphique 'data-sin/explicite-0.10-10000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# On constate que les modes ont un temps caracteristique plus petit que celui de la valeur moyenne.

# %% [markdown]
# ### Pour $ \alpha = 0.6$ et $ N_t = 1000$

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-sin/explicite-0.60-1000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=1000
#  Le graphique 'data-sin/explicite-0.60-1000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# On observe bien l'instabilité de la méthode explicite pour des conditions initiales telles que $\alpha > \frac{1}{2}$

# %% [markdown]
# ##  Méthode Implicite
# ### Pour $ \alpha = 0.1$ et $ N_t = 1000$

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-sin/implicite-0.10-1000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=1000
#  Le graphique 'data-sin/implicite-0.10-1000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# ### Pour $ \alpha = 0.1$ et $ N_t = 10000$

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-sin/implicite-0.10-10000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=10000
#  Le graphique 'data-sin/implicite-0.10-10000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# ### Pour $ \alpha = 0.6$ et $ N_t = 1000$

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-sin/implicite-0.60-1000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=1000
#  Le graphique 'data-sin/implicite-0.60-1000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# ## Méthode Crank Nicolson

# %% [markdown]
# ### Pour $ \alpha = 0.1$ et $ N_t = 1000$

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-sin/cranknic-0.10-1000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=1000
#  Le graphique 'data-sin/cranknic-0.10-1000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# ### Pour $ \alpha = 0.1$ et $ N_t = 10000$

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-sin/cranknic-0.10-10000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=10000
#  Le graphique 'data-sin/cranknic-0.10-10000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# ### Pour $ \alpha = 0.6$ et $ N_t = 1000$

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-sin/cranknic-0.60-1000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=1000
#  Le graphique 'data-sin/cranknic-0.60-1000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# ### Pour $ \alpha = 1.0 $ et $ N_t = 1000 $

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-sin/cranknic-1.00-1000.dat"
#fichier = "explicite.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=1000
#  Le graphique 'data-sin/cranknic-1.00-1000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# ## Observations
#
# * On voit que les hautes fréquences ont des temps caractéristiques de diffusion plus petits que les hautes fréquences.
#
# * On observe que lorsqu'on augmente alpha la diffusion a lieu plus rapidement. On arrive donc à une configuration d'équilibre à des temps caracteristiques plus petits.
#
# * Ici on compare la méthode explicite aux méthodes implicite et Crank-Nicolson qui sont toujours stables pour toutes les valeurs de $\delta t$ et $\delta x$. On a observé une instabilité pour la méthode explicite à $\alpha = 0.6$

# %% [markdown]
# ## Pour la condition initiale de marche

# %% [markdown]
# ### Pour $\alpha = 0.1 $ et $ N_t = 1000$
#
# #### Méthode explicite

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys

#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-step/explicite-0.10-1000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=1000
#  Le graphique 'data-step/explicite-0.10-1000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# #### Méthode implicite

# %%
# (python 3)
import numpy as np
import matplotlib.pyplot as plt
import sys
#
#------ PARAMETRES a EDITER -------------------------#
# nom du fichier de donnees (ayant 1 ligne d'en-tete)
fichier = "data-step/implicite-0.10-1000.dat"
#fichier = "implicite.dat"
#fichier = "cranknic.dat"
nech   = 10              # nombre d'instants affiches (echantillonnage regulier)
#----------------------------------------------------#

titre  = 'Diffusion : fichier "%s" '%fichier

# Lecture de la ligne d'entete : nx+2 nt dx dt alpha
try:
    fp = open(fichier,"r")
except:
    print( " Erreur d'ouverture du fichier '%s' ."%fichier)
    exit(1)
    
params = fp.readline().strip().replace("#","").split()
fp.close()

try:
    nx = int( params[0] ) # nbr de points, bords inclus
    nt = int( params[1] ) # nbr d'instants attendus
    dx = float( params[2] ) # pas en espace
    dt = float( params[3] ) # pas en temps
    alpha = float( params[4] ) # parametre alpha
except:
    print (" ! La ligne d'en-tete n'est pas au format attendu :")
    print(" (nx+2 nt dx dt alpha) : ", params)
    dx = 1.
    dt = -1.
    alpha = -1.

# Lecture des donnees : apres la 1ere ligne
data = np.loadtxt( fichier, skiprows=1)
# nombre effectif d'instants et de points
nt = data.shape[0]
nx = data.shape[1]
print(" Nx=%d , Nt=%d"%(nx,nt))
params= "$\\alpha = %g , \delta t=%g , \delta x=%g$"%(alpha,dt,dx)

# Axe des X :
x = dx*np.linspace(0,nx-1,nx)
# pas d'echantillonnage en temps : nombre d'instants sautes
pech = max(1, int((nt-1)/(nech-1)) )

# Affichage :
plt.rc('text', usetex=True)
plt.figure( figsize=(11.69,8.27) )
plt.plot(x, data[0], '-', label='t=0')
for k in range(1,nech-1):
    plt.plot(x, data[pech*k], '-')
plt.plot(x, data[nt-1], '-', label='t=%g'%(dt*(nt-1)))
plt.xlabel("position $x$")
plt.ylabel("u(x,t)")
plt.title( r"%s $\quad$ %s"%(titre, params) )
plt.legend()
plt.grid(True)

# Nom du graphique : identique a celui du fichier
graphname = fichier[ : fichier.rfind(".")] + ".pdf"
plt.savefig( graphname, format="pdf")
print( " Le graphique '%s' a ete cree."%graphname )
print( "\n Fermer la figure pour terminer.\n" )
plt.show()
# Out:
#  Nx=121 , Nt=1000
#  Le graphique 'data-step/implicite-0.10-1000.pdf' a ete cree.
#
#  Fermer la figure pour terminer.

# %% [markdown]
# #### Méthode de Clark Nicolson

# %% [markdown]
# ### Pour $\alpha = 1.0 $ et $ N_t = 1000$
#
# #### Méthode explicite
